# %% [markdown]
# # 데이터 시각화 연습문제 (3) - seaborn 막대, 빈도 그래프 풀이

# %% [markdown]
# ## #01. 작업준비

# %% [markdown]
# 1. 패키지 참조

# %%
import sys
from matplotlib import pyplot as plt
from pandas import read_excel
import seaborn as sb
import numpy as np

# %% [markdown]
# 2. 데이터 가져오기

# %%
# 데이터 확인 후 index 설정
mpg_df = read_excel("https://data.hossam.kr/D01/mpg.xlsx", index_col="id")
mpg_df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# id
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# id
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %% [markdown]
# 3. 데이터 전처리
#
# 빈도 그래프의 내부 기능에서 전처리를 행하기 때문에 category 전처리는 본인의 선택

# %%
df = mpg_df.astype({'manufacturer': 'category', 'model': 'category', 'year': 'category',
                    'cyl': 'category', 'trans': 'category', 'drv': 'category',
                    'fl': 'category', 'class': 'category'})
df.dtypes
# Out:
# manufacturer    category
# model           category
# displ            float64
# year            category
# cyl             category
# trans           category
# drv             category
# cty                int64
# hwy                int64
# fl              category
# class           category
# dtype: object

# %% [markdown]
# 4. 그래프 전역 설정
#
# 삼항 연산자
#
# 변수 = 참인경우_할당될_값 if 조건식 else 거짓인경우_할당될_값

# %%
plt.rcParams['font.family'] = "AppleGothic" if sys.platform == "darwin" else "Malgun Gothic"
plt.rcParams["font.size"] = 10
plt.rcParams["figure.figsize"] = (15, 5)
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## #02. 문제 풀이

# %% [markdown]
# ### 문제1
#
# 자동차 제조사별로 출시한 자동차 수를 하나의 그래프로 시각화

# %% [markdown]
# `catplot()` 함수 사용

# %%
g = sb.catplot(data=df, x='manufacturer', kind='count')

g.fig.set_figwidth(15)
g.fig.set_figheight(5)

plt.title("제조사별 자동차 모델 수")
plt.show()
plt.close()

# %% [markdown]
# `countplot()` 함수 사용

# %%
sb.countplot(data=df, x="manufacturer")
plt.title("제조사별 자동차 모델 수")
plt.show()
plt.close()

# %% [markdown]
# ### 문제2
#
# 자동차 제조사에 따른 자동차 수를 제조년도를 범주로 하여 하나의 그래프로 시각화

# %%
g = sb.catplot(data=df, x='manufacturer', kind='count', hue='year')

g.fig.set_figwidth(15)
g.fig.set_figheight(5)

plt.title("제조사별 자동차 모델 수")
plt.show()
plt.close()

# %%
sb.countplot(data=df, x="manufacturer", hue='year')
plt.legend(bbox_to_anchor=(1.1,1))
plt.title("제조사별 자동차 모델 수")
plt.show()
plt.close()

# %% [markdown]
# ### 문제3
#
# 구동방식에 따른 자동차 수를 하나의 그래프로 시각화

# %%
g = sb.catplot(data=df, x='drv', kind='count')

g.fig.set_figwidth(5)
g.fig.set_figheight(3)

plt.title("구동방식에 따른 자동차 수")
plt.show()
plt.close()

# %%
sb.countplot(data=df, x='drv')
plt.title("구동방식에 따른 자동차 수")
plt.show()
plt.close()

# %% [markdown]
# ### 문제4
#
# 자동차 구동 방식에 따른 도심 연비 평균을 하나의 그래프로 시각화

# %% [markdown]
# `barplot()` 함수

# %%
plt.rcParams["figure.figsize"] = (10, 4)

sb.barplot(data=df, x='drv', y='cty', estimator='mean')
plt.title("구동방식별 평균 도심 연비")
plt.xticks([0, 1, 2], ['4륜구동', '전륜구동', '후륜구동'])
plt.show()
plt.close()

# %% [markdown]
# ### 문제5
#
# 자동차 제조사에 따른 도심 연비 평균과 고속도로 연비 평균을 서브플롯 형태로 시각화

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(25, 7))

fig.subplots_adjust(wspace=0.2)

fig.suptitle('제조사별 연비 비교', fontsize=30)

sb.barplot(data=df, x='manufacturer', y='cty', estimator='mean', ax=ax1)
sb.barplot(data=df, x='manufacturer', y='hwy', estimator='mean', ax=ax2)

ax1.title.set_text("평균 도심 연비")
ax2.title.set_text("평균 고속도로 연비")

plt.show()
plt.close()

# %% [markdown]
# ### 문제6
#
# 배기량과 도심연비, 배기량과 고속도로 연비의 상관관계를 확인
#
# 서브플롯에 각 그래프를 시각화 하고 추세선을 포함

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5))

fig.subplots_adjust(wspace=0.1)

fig.suptitle('배기량과 연비의 상관관계', fontsize=25)

sb.regplot(data=df, x='displ', y='cty', ax=ax1,
           line_kws={'color': 'red'}, scatter_kws={'color': 'blue'})
sb.regplot(data=df, x='displ', y='hwy', ax=ax2)

ax1.title.set_text("배기량과 도심 연비")
ax2.title.set_text("배기량과 고속도로 연비")

plt.show()
plt.close()

# %% [markdown]
# ### 문제7

# %%
# df1 = df.copy()
# df1['평균'] = df1[df1.columns[7:9]].mean(axis=1)
# df1

# %%
df['평균연비'] = df.loc[:, 'cty':'hwy'].mean(axis=1)
df
# Out:
#     manufacturer   model  displ  year cyl       trans drv  cty  hwy fl  \
# id
# 1           audi      a4    1.8  1999   4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999   4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008   4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008   4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999   6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ..         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008   4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008   4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999   6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999   6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008   6    auto(s6)   f   17   26  p
#
#        class  평균연비
# id
# 1    compact  23.5
# 2    compact  25.0
# 3    compact  25.5
# 4    compact  25.5
# 5    compact  21.0
# ..       ...   ...
# 230  midsize  23.5
# 231  midsize  25.0
# 232  midsize  21.0
# 233  midsize  22.0
# 234  midsize  21.5
#
# [234 rows x 12 columns]

# %%
평균값 = df['평균연비'].mean()
평균값
# Out:
# 20.14957264957265

# %%
df['평가'] = np.where(df['평균연비'] > 평균값, 'Pass', 'Fail')
df
# Out:
#     manufacturer   model  displ  year cyl       trans drv  cty  hwy fl  \
# id
# 1           audi      a4    1.8  1999   4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999   4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008   4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008   4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999   6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ..         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008   4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008   4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999   6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999   6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008   6    auto(s6)   f   17   26  p
#
#        class  평균연비    평가
# id
# 1    compact  23.5  Pass
# 2    compact  25.0  Pass
# 3    compact  25.5  Pass
# 4    compact  25.5  Pass
# 5    compact  21.0  Pass
# ..       ...   ...   ...
# 230  midsize  23.5  Pass
# 231  midsize  25.0  Pass
# 232  midsize  21.0  Pass
# 233  midsize  22.0  Pass
# 234  midsize  21.5  Pass
#
# [234 rows x 13 columns]

# %% [markdown]
# 보너스 : 평균의 합

# %%
평균합 = df['평균연비'].sum()
평균합
# Out:
# 4715.0

# %%
df['연비효율'] = df['평균연비'] / 평균값 * 100
df
# Out:
#     manufacturer   model  displ  year cyl       trans drv  cty  hwy fl  \
# id
# 1           audi      a4    1.8  1999   4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999   4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008   4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008   4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999   6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ..         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008   4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008   4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999   6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999   6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008   6    auto(s6)   f   17   26  p
#
#        class  평균연비    평가        연비효율
# id
# 1    compact  23.5  Pass  116.627784
# 2    compact  25.0  Pass  124.072110
# 3    compact  25.5  Pass  126.553552
# 4    compact  25.5  Pass  126.553552
# 5    compact  21.0  Pass  104.220573
# ..       ...   ...   ...         ...
# 230  midsize  23.5  Pass  116.627784
# 231  midsize  25.0  Pass  124.072110
# 232  midsize  21.0  Pass  104.220573
# 233  midsize  22.0  Pass  109.183457
# 234  midsize  21.5  Pass  106.702015
#
# [234 rows x 14 columns]

# %%
조건 = [
    (df['연비효율'] >= 90),
    (df['연비효율'] >= 80),
    (df['연비효율'] >= 70)
]

값 = ['A', 'B', 'C']

df['등급'] = np.select(조건, 값, default='D')
df
# Out:
#     manufacturer   model  displ  year cyl       trans drv  cty  hwy fl  \
# id
# 1           audi      a4    1.8  1999   4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999   4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008   4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008   4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999   6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ..         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008   4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008   4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999   6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999   6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008   6    auto(s6)   f   17   26  p
#
#        class  평균연비    평가        연비효율 등급
# id
# 1    compact  23.5  Pass  116.627784  A
# 2    compact  25.0  Pass  124.072110  A
# 3    compact  25.5  Pass  126.553552  A
# 4    compact  25.5  Pass  126.553552  A
# 5    compact  21.0  Pass  104.220573  A
# ..       ...   ...   ...         ... ..
# 230  midsize  23.5  Pass  116.627784  A
# 231  midsize  25.0  Pass  124.072110  A
# 232  midsize  21.0  Pass  104.220573  A
# 233  midsize  22.0  Pass  109.183457  A
# 234  midsize  21.5  Pass  106.702015  A
#
# [234 rows x 15 columns]

# %%
fig, ((ax11, ax12), (ax21, ax22), (ax31, ax32)) = plt.subplots(3, 2, figsize=(20, 20))

# 자동차 구동방식별 평가에 대한 빈도
sb.countplot(data=df, x='drv', hue='평가', ax=ax11)

# 자동차 구동방식별 등급에 대한 빈도
sb.countplot(data=df, x='drv', hue='등급', ax=ax12)

# 자동차 연료 종류 평가에 대한 빈도
sb.countplot(data=df, x='fl', hue='평가', ax=ax21)

# 자동차 연료 종류 등급에 대한 빈도
sb.countplot(data=df, x='fl', hue='등급', ax=ax22)

# 자동차 분류별 평가에 대한 빈도
sb.countplot(data=df, x='class', hue='평가', ax=ax31)

# 자동차 분류별 등급에 대한 빈도
sb.countplot(data=df, x='class', hue='등급', ax=ax32)

plt.show()
plt.close()
