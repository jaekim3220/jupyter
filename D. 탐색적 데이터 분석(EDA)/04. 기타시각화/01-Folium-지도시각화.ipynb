# %% [markdown]
# # 지도 시각화

# %% [markdown]
# ## #01. 패키지 참조
#
# folium 패키지가 설치되어 있어야 한다.
#
# folium을 사용한 지도 시각화

# %%
import folium
from pandas import read_excel
from os import path, mkdir

# %% [markdown]
# ## #02. 지도 표현하기

# %% [markdown]
# ### 1. 지도 객체 생성
#
# 지도의 중심이 되는 위도와 경도를 설정
#
# URL에서 위도와 경도를 추출해서 사용

# %%
# zoom_start: 배율 1~22
map_osm = folium.Map(location=[37.5004444, 127.0313861], zoom_start=17)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a11b7c9892d4cbabcff629458345bc1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a11b7c9892d4cbabcff629458345bc1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a11b7c9892d4cbabcff629458345bc1 = L.map(
#                 &quot;map_9a11b7c9892d4cbabcff629458345bc1&quot;,
#                 {
#                     center: [37.5004444, 127.0313861],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cce1aedb43e4028185913444a57fad13 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a11b7c9892d4cbabcff629458345bc1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 2. 지도객체에 마커 추가
#
# 일반 마커
# 아이콘 색상값 종류
#
# >'lightgreen', 'darkgreen', 'darkblue', 'cadetblue', 'orange', 'lightred', 'darkred', 'green', 'blue', 'black', 'lightblue', 'white', 'lightgray', 'red', 'pink', 'beige', 'gray', 'purple', 'darkpurple'

# %%
# 새로운 지도 객체 생성
map_osm1 = folium.Map(location=[37.5004444, 127.0313861], zoom_start=17)

# 마커 객체 생성
# 마커가 표시될 위치 [위도,경도], 클리시 표시될 메시지, 아이콘 색상
marker1 = folium.Marker([37.5004444, 127.0313861], 
                        popup='메가스터디IT아카데미 강남', 
                        icon=folium.Icon(color='darkred'))

marker1.add_to(map_osm1)    #마커 객체를 지도에 추가
map_osm1    #지도 표시
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5b0b8ec9a7441c84556995d23a4b23f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5b0b8ec9a7441c84556995d23a4b23f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5b0b8ec9a7441c84556995d23a4b23f = L.map(
#                 &quot;map_b5b0b8ec9a7441c84556995d23a4b23f&quot;,
#                 {
#                     center: [37.5004444, 127.0313861],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_624167da3ebbd202bcafc8a5e257a633 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b5b0b8ec9a7441c84556995d23a4b23f);
#
#
#             var marker_d009568f5e5cae861dc7bb7217c0922b = L.marker(
#                 [37.5004444, 127.0313861],
#                 {}
#             ).addTo(map_b5b0b8ec9a7441c84556995d23a4b23f);
#
#
#             var icon_3258658c0e23ffabe7f5ef3c6f4df26d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d009568f5e5cae861dc7bb7217c0922b.setIcon(icon_3258658c0e23ffabe7f5ef3c6f4df26d);
#
#
#         var popup_35f9bb81b8a9a1ae64fa03896497431c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0644a0ec618fc04815575defca32c746 = $(`&lt;div id=&quot;html_0644a0ec618fc04815575defca32c746&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;메가스터디IT아카데미 강남&lt;/div&gt;`)[0];
#                 popup_35f9bb81b8a9a1ae64fa03896497431c.setContent(html_0644a0ec618fc04815575defca32c746);
#
#
#
#         marker_d009568f5e5cae861dc7bb7217c0922b.bindPopup(popup_35f9bb81b8a9a1ae64fa03896497431c)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 사용자 지정 아이콘, HTML 팝업

# %%
# 새로운 지도 객체 생성
map_osm2 = folium.Map(location=[37.5004444, 127.0313861], zoom_start=17)

# HTML을 사용한 팝업
popup_html = folium.Popup("<div style='white-space: nowrap'><h3>메가스터디IT아카데미 강남</h3><img src='https://img.megastudyacademy.co.kr/campus/iws_html_img/it_brand/sec08_img01.png' width='100%'><br/><p>tel: <a href='tel:07043380972'>070-4338-0972</a></p><p>서울특별시 강남구 강남대로94길 삼경빌딩 2층</p></div>", parse_html=False)

# 사용자 지정 아이콘 이미지 사용
# 온라인 상의 URL, 내 컴퓨터 상의 상대,절대경로 모두 가능
icon_img = folium.features.CustomIcon('C:\\Users\\jehyu\\Desktop\\nationalsupport\\jupyter\\D. 탐색적 데이터 분석\\04. 데이터 구간화\\3179575.png', icon_size=(50, 50))

# 마커 객체 생성
marker2 = folium.Marker([37.5004444, 127.0313861], 
                        popup=popup_html,
                        icon=icon_img)

marker2.add_to(map_osm2) # 마커 객체를 지도에 추가

# 웹 페이지 파일이 저장될 폴더 생성
if not path.exists('output'):
    mkdir('output')

map_osm2.save('output/map_osm2.html') #파일이 저장될 위치

map_osm2                 # 지도 표시하기
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f83d4707d920d4b315284490ebd9b48a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f83d4707d920d4b315284490ebd9b48a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f83d4707d920d4b315284490ebd9b48a = L.map(
#                 &quot;map_f83d4707d920d4b315284490ebd9b48a&quot;,
#                 {
#                     center: [37.5004444, 127.0313861],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81f5a0b2adf4eff02d4166d0785e7fdf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f83d4707d920d4b315284490ebd9b48a);
#
#
#             var marker_912620b4e92fcaa6798681aa4afbc054 = L.marker(
#                 [37.5004444, 127.0313861],
#                 {}
#             ).addTo(map_f83d4707d920d4b315284490ebd9b48a);
#
#
#         var custom_icon_4d4ddee3864e5bb18074e0f45f6ed43d = L.icon({&quot;iconSize&quot;: [50, 50], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_912620b4e92fcaa6798681aa4afbc054.setIcon(custom_icon_4d4ddee3864e5bb18074e0f45f6ed43d);
#
#
#         var popup_06b74faef2f13caabc770ccb293492b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b32d4f744956ccb87347cc70ba09d656 = $(`&lt;div id=&quot;html_b32d4f744956ccb87347cc70ba09d656&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;div style=&#x27;white-space: nowrap&#x27;&gt;&lt;h3&gt;메가스터디IT아카데미 강남&lt;/h3&gt;&lt;img src=&#x27;https://img.megastudyacademy.co.kr/campus/iws_html_img/it_brand/sec08_img01.png&#x27; width=&#x27;100%&#x27;&gt;&lt;br/&gt;&lt;p&gt;tel: &lt;a href=&#x27;tel:07043380972&#x27;&gt;070-4338-0972&lt;/a&gt;&lt;/p&gt;&lt;p&gt;서울특별시 강남구 강남대로94길 삼경빌딩 2층&lt;/p&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_06b74faef2f13caabc770ccb293492b8.setContent(html_b32d4f744956ccb87347cc70ba09d656);
#
#
#
#         marker_912620b4e92fcaa6798681aa4afbc054.bindPopup(popup_06b74faef2f13caabc770ccb293492b8)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 원형 마커(범위지정)

# %%
# 새로운 지도 객체 생성
map_osm3 = folium.Map(location=[37.5004444, 127.0313861], zoom_start=17)

# 마커 객체 생성
marker1 = folium.Marker([37.5004444, 127.0313861],  
                        icon=folium.Icon(color='orange'))

# 원형마커 
marker2 = folium.CircleMarker([37.5004444, 127.0313861], 
                              radius=100,                 # 범위
                              color='#3186cc',            # 선 색상
                              fill_color='#3186cc')       # 면 색상

# 원형 마커 위에 아이콘 마커 올리기
marker2.add_to(map_osm3)
marker1.add_to(map_osm3)

# 마커 객체 생성
marker3 = folium.Marker([37.5005454, 127.0314871],  
                        icon=folium.Icon(color='red'))

map_osm3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89f80d7027d2f20646694c5f66d5a9b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89f80d7027d2f20646694c5f66d5a9b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89f80d7027d2f20646694c5f66d5a9b1 = L.map(
#                 &quot;map_89f80d7027d2f20646694c5f66d5a9b1&quot;,
#                 {
#                     center: [37.5004444, 127.0313861],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_224cb1e276e874c32640d85736ddccc9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_89f80d7027d2f20646694c5f66d5a9b1);
#
#
#             var circle_marker_ff80f09f805b2fd2a9de9bd0c13266cf = L.circleMarker(
#                 [37.5004444, 127.0313861],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3186cc&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_89f80d7027d2f20646694c5f66d5a9b1);
#
#
#             var marker_cafdb9d22ca0315c66026b9041eb85a9 = L.marker(
#                 [37.5004444, 127.0313861],
#                 {}
#             ).addTo(map_89f80d7027d2f20646694c5f66d5a9b1);
#
#
#             var icon_5653fe3011b05ab3cb903a87f85b6133 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cafdb9d22ca0315c66026b9041eb85a9.setIcon(icon_5653fe3011b05ab3cb903a87f85b6133);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 3. 다른 형태의 지도

# %% [markdown]
# #### 평면도

# %%
# zoom_start: 배율 1~22
map_osm = folium.Map(location=[37.5005454, 127.0314871], zoom_start=17, 
                      tiles='Stamen Toner')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9685c4a66cfbfd2db77425f1633f2afd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9685c4a66cfbfd2db77425f1633f2afd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9685c4a66cfbfd2db77425f1633f2afd = L.map(
#                 &quot;map_9685c4a66cfbfd2db77425f1633f2afd&quot;,
#                 {
#                     center: [37.5005454, 127.0314871],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2642e1c8ab37bbad73f77537610871c7 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9685c4a66cfbfd2db77425f1633f2afd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 지형도

# %%
# zoom_start: 배율 1~22
map_osm = folium.Map(location=[37.5005454, 127.0314871], zoom_start=11, 
                     tiles='Stamen Terrain')
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd8586a15977107ab6758911d3b60b7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd8586a15977107ab6758911d3b60b7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd8586a15977107ab6758911d3b60b7c = L.map(
#                 &quot;map_fd8586a15977107ab6758911d3b60b7c&quot;,
#                 {
#                     center: [37.5005454, 127.0314871],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aaac3867e1935a3a7b1f326d4c95dad7 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fd8586a15977107ab6758911d3b60b7c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## #03. (예제) 서울의 고등학교 분포 확인하기

# %% [markdown]
# ### 1.데이터 준비
#
# 전국 초,중,고 학교 위치 엑셀 파일을 원격으로 내려받아 데이터프레임으로 변환 (다소 시간이 소요된다.)
#
# >데이터 출처: 공공데이터 포털

# %%
xlsx = read_excel("https://data.hossam.kr/D04/school.xlsx")
xlsx
# Out:
#              학교ID          학교명 학교급구분        설립일자 설립형태 본교분교구분 운영상태  \
# 0      B000004204       한울초등학교  초등학교  2008-09-01   공립     본교   운영
# 1      B000011476  수원농생명과학고등학교  고등학교  1936-07-01   공립     본교   운영
# 2      B000009647        녹양중학교   중학교  2008-03-01   공립     본교   운영
# 3      B000005955       초락초등학교  초등학교  1959-04-02   공립     본교   운영
# 4      B000005385       상봉초등학교  초등학교  1946-09-01   공립     본교   운영
# ...           ...          ...   ...         ...  ...    ...  ...
# 11983  B000003371     대전옥계초등학교  초등학교  1982-12-09   공립     본교   운영
# 11984  B000003345       성덕초등학교  초등학교  2011-03-11   공립     본교   운영
# 11985  B000005441       이월초등학교  초등학교  1920-04-01   공립     본교   운영
# 11986  B000009875        해안중학교   중학교  1979-03-08   공립     본교   운영
# 11987  B000011237        초계중학교   중학교  1952-06-01   공립     본교   운영
#
#                           소재지지번주소                                    소재지도로명주소  \
# 0             경기도 화성시 향남읍 행정리 442        경기도 화성시 향남읍 행정중앙1로 25 . 한울초등학교 (향남읍)
# 1             경기도 수원시 장안구 영화동 109         경기도 수원시 장안구 광교산로 13 (영화동.농생명과학고등학교)
# 2              경기도 의정부시 녹양동 191-5              경기도 의정부시 체육로 187 . 녹양중학교 (녹양동)
# 3         충청남도 당진시 석문면 초락도리 210-3                  충청남도 당진시 석문면 샛터말길 35 (석문면)
# 4      충청북도 청주시 흥덕구 오송읍 상봉리 242-1       충청북도 청주시 흥덕구 오송읍 상봉길 9 . 상봉초등학교 (오송읍)
# ...                           ...                                         ...
# 11983             대전광역시 중구 옥계동 65             대전광역시 중구 모암로 35 (옥계동. 대전옥계초등학교)
# 11984          광주광역시 광산구 장덕동 1042            광주광역시 광산구 풍영로 313 . 성덕초등학교 (장덕동)
# 11985        충청북도 진천군 이월면 송림리 667         충청북도 진천군 이월면 송림6길 26 . 이월초등학교 (이월면)
# 11986          강원도 양구군 해안면 현리 143                 강원도 양구군 해안면 펀치볼로 1279 (해안면)
# 11987         경상남도 합천군 초계면 아막리 99  경상남도 합천군 초계면 초계중앙로 83 . 초계중학교 (초계면. 초계중학교)
#
#        시도교육청코드    시도교육청명  교육지원청코드        교육지원청명        생성일자        변경일자  \
# 0      7530000    경기도교육청  7679000  경기도화성오산교육지원청  2013-11-29  2022-10-06
# 1      7530000    경기도교육청  7541000    경기도수원교육지원청  2013-11-29  2022-10-06
# 2      7530000    경기도교육청  7561000   경기도의정부교육지원청  2013-11-29  2022-10-06
# 3      8140000   충청남도교육청  8291000   충청남도당진교육지원청  2013-11-29  2022-10-06
# 4      8000000   충청북도교육청  8011000   충청북도청주교육지원청  2013-11-29  2022-10-06
# ...        ...       ...      ...           ...         ...         ...
# 11983  7430000  대전광역시교육청  7441000  대전광역시동부교육지원청  2013-11-29  2022-10-06
# 11984  7380000  광주광역시교육청  7401000  광주광역시서부교육지원청  2013-11-29  2022-10-06
# 11985  8000000   충청북도교육청  8081000   충청북도진천교육지원청  2013-11-29  2022-10-06
# 11986  7800000    강원도교육청  7951000    강원도양구교육지원청  2013-11-29  2022-10-06
# 11987  9010000   경상남도교육청  9221000   경상남도합천교육지원청  2013-11-29  2022-10-06
#
#               위도          경도     데이터기준일자   제공기관코드            제공기관명
# 0      37.126961  126.917854  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 1      37.295154  127.019450  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 2      37.761864  127.028084  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 3      36.993080  126.510472  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 4      36.638251  127.286142  2023-03-22  C738100  청주대학교 지방교육재정연구원
# ...          ...         ...         ...      ...              ...
# 11983  36.301199  127.449039  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 11984  35.199148  126.814301  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 11985  36.931076  127.431922  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 11986  38.283771  128.135686  2023-03-22  C738100  청주대학교 지방교육재정연구원
# 11987  35.560066  128.270502  2023-03-22  C738100  청주대학교 지방교육재정연구원
#
# [11988 rows x 20 columns]

# %% [markdown]
# ### 2.데이터 전처리
#
# 사용할 필드만 추출

# %%
df = xlsx.filter(['학교명', '학교급구분', '소재지도로명주소', '위도', '경도'])
df
# Out:
#                학교명 학교급구분                                    소재지도로명주소  \
# 0           한울초등학교  초등학교        경기도 화성시 향남읍 행정중앙1로 25 . 한울초등학교 (향남읍)
# 1      수원농생명과학고등학교  고등학교         경기도 수원시 장안구 광교산로 13 (영화동.농생명과학고등학교)
# 2            녹양중학교   중학교              경기도 의정부시 체육로 187 . 녹양중학교 (녹양동)
# 3           초락초등학교  초등학교                  충청남도 당진시 석문면 샛터말길 35 (석문면)
# 4           상봉초등학교  초등학교       충청북도 청주시 흥덕구 오송읍 상봉길 9 . 상봉초등학교 (오송읍)
# ...            ...   ...                                         ...
# 11983     대전옥계초등학교  초등학교             대전광역시 중구 모암로 35 (옥계동. 대전옥계초등학교)
# 11984       성덕초등학교  초등학교            광주광역시 광산구 풍영로 313 . 성덕초등학교 (장덕동)
# 11985       이월초등학교  초등학교         충청북도 진천군 이월면 송림6길 26 . 이월초등학교 (이월면)
# 11986        해안중학교   중학교                 강원도 양구군 해안면 펀치볼로 1279 (해안면)
# 11987        초계중학교   중학교  경상남도 합천군 초계면 초계중앙로 83 . 초계중학교 (초계면. 초계중학교)
#
#               위도          경도
# 0      37.126961  126.917854
# 1      37.295154  127.019450
# 2      37.761864  127.028084
# 3      36.993080  126.510472
# 4      36.638251  127.286142
# ...          ...         ...
# 11983  36.301199  127.449039
# 11984  35.199148  126.814301
# 11985  36.931076  127.431922
# 11986  38.283771  128.135686
# 11987  35.560066  128.270502
#
# [11988 rows x 5 columns]

# %% [markdown]
# #### 서울시의 고등학교만 추출
#
# 학교급구분 필드 값이 고등학교이고, 소재지도로명주소에 서울 이라는 단어가 포함된 경우

# %% [markdown]
# LIKE 연산 : 컬럼이름.str.contains('검색어')

# %%
df2 = df.query("학교급구분 == '고등학교' and 소재지도로명주소.str.contains('울산')")
df2
# Out:
#                학교명 학교급구분                                          소재지도로명주소  \
# 250       울산중앙고등학교  고등학교                     울산광역시 중구 난곡로 33 (태화동. 중앙고등학교)
# 715       울산제일고등학교  고등학교                울산광역시 남구 남부순환도로 107 (옥동. 울산제일고등학교)
# 719         남목고등학교  고등학교                울산광역시 동구 방어진순환도로 1200 (서부동.남목고등학교)
# 724         성신고등학교  고등학교                   울산광역시 중구 성신고교길 26 (복산동. 성신고등학교)
# 735       울산예술고등학교  고등학교           울산광역시 울주군 웅촌면 웅촌로 621-6 (웅촌면. 울산예술고등학교)
# 842         무거고등학교  고등학교               울산광역시 남구 대학로1번길 17-28 (무거동. 무거고등학교)
# 856         문현고등학교  고등학교                    울산광역시 동구 화잠7길 25 (방어동. 문현고등학교)
# 1031        울산고등학교  고등학교                  울산광역시 중구 도화골15길 15 (복산동. 울산고등학교)
# 1201      울산동천고등학교  고등학교                     울산광역시 북구 고래로 54 (천곡동. 동천고등학교)
# 1239      현대공업고등학교  고등학교       울산광역시 동구 미포로 122 . 현대공업고등학교 (동부동. 현대공업고등학교)
# 1521      울산여자고등학교  고등학교               울산광역시 남구 삼산로9번길 16 . 울산여자고등학교 (신정동)
# 1911      삼일여자고등학교  고등학교              울산광역시 남구 두왕로190번길 59 (선암동. 삼일여자고등학교)
# 1963      울산경의고등학교  고등학교             울산광역시 울주군 상북면 상북로 248 (상북면. 울산경의고등학교)
# 2037      학성여자고등학교  고등학교                  울산광역시 중구 화합로 466 (약사동. 학성여자고등학교)
# 2049        다운고등학교  고등학교                    울산광역시 중구 다운로 180 (다운동. 다운고등학교)
# 2198      울산강남고등학교  고등학교                       울산광역시 남구 팔등로 115 . 22 (신정동)
# 2199        우신고등학교  고등학교                  울산광역시 남구 대학로1번길 29 (무거동. 우신고등학교)
# 2259        달천고등학교  고등학교                   울산광역시 북구 달천철장길 23 (달천동. 달천고등학교)
# 2715        호계고등학교  고등학교                   울산광역시 북구 동대11길 31 (호계동. 호계고등학교)
# 3122        화암고등학교  고등학교                    울산광역시 동구 화암7길 55 (방어동. 화암고등학교)
# 3529        삼산고등학교  고등학교                울산광역시 남구 돋질로339번길 13 (삼산동. 삼산고등학교)
# 3626      울산공업고등학교  고등학교             울산광역시 남구 중앙로204번길 49 . 울산공업고등학교 (신정동)
# 3659        매곡고등학교  고등학교                    울산광역시 북구 매산로 45 . 매곡고등학교 (매곡동)
# 4527        신정고등학교  고등학교                    울산광역시 남구 문수로 458 (신정동. 신정고등학교)
# 4621      울산상업고등학교  고등학교            울산광역시 울주군 범서읍 장검길 11.울산상업고등학교 울산상업고등학교
# 4906   울산스포츠과학고등학교  고등학교              울산광역시 북구 산음3길 16 . 울산스포츠과학고등학교 (산하동)
# 5052        강동고등학교  고등학교                     울산광역시 북구 화암4길 8 (산하동. 강동고등학교)
# 5680      성광여자고등학교  고등학교                           울산광역시 남구 남부순환도로 97 (옥동)
# 5898        문수고등학교  고등학교                   울산광역시 남구 울밀로 2905 (무거동. 문수고등학교)
# 6025        무룡고등학교  고등학교                    울산광역시 북구 사청1길 30 (연암동. 무룡고등학교)
# 6259      울산산업고등학교  고등학교                      울산광역시 울주군 삼남면 반구대로 675 (삼남면)
# 6282        학성고등학교  고등학교                     울산광역시 남구 문수로 436 (신정동.학성고등학교)
# 6341      신선여자고등학교  고등학교                울산광역시 남구 수암로178번길 14 (야음동. 야음교육단지)
# 6553        현대고등학교  고등학교                    울산광역시 동구 봉수로 455 (서부동. 현대고등학교)
# 6768      현대청운고등학교  고등학교                       울산광역시 동구 방어진순환도로 1077 (서부동)
# 7046        화봉고등학교  고등학교                    울산광역시 북구 화동로 47 . 화봉고등학교 (화봉동)
# 7201     울산외국어고등학교  고등학교  울산광역시 북구 중산동로 32-46 . 울산외국어고등학교 (중산동. 울산외국어고등학교)
# 7234        대현고등학교  고등학교           울산광역시 남구 수암로 164 . 대현고등학교 (야음동. 야음교육단지)
# 7242        대송고등학교  고등학교                    울산광역시 동구 봉수로 210 (화정동. 대송고등학교)
# 7266        함월고등학교  고등학교                            울산광역시 중구 종가3길 25 (유곡동)
# 8164      울산과학고등학교  고등학교                   울산광역시 울주군 상북면 도동신리로 . 117 (상북면)
# 8340    울산마이스터고등학교  고등학교                  울산광역시 북구 율동6길 7 (효문동.울산마이스터고등학교)
# 8633    울산생활과학고등학교  고등학교                 울산광역시 동구 학문로 70 (화정동. 울산생활과학고등학교)
# 8666        범서고등학교  고등학교                울산광역시 울주군 범서읍 대리로 69 (범서읍. 범서고등학교)
# 8994    울산여자상업고등학교  고등학교                울산광역시 남구 두왕로 304 (신정동. 울산여자상업고등학교)
# 9423     울산애니원고등학교  고등학교                울산광역시 중구 성안11길 21 (성안동. 울산애니원고등학교)
# 9666       방어진고등학교  고등학교                    울산광역시 동구 학문로 50 (화정동. 방어진고등학교)
# 9812        남창고등학교  고등학교           울산광역시 울주군 온양읍 태화7길 43-16 . 남창고등학교 (온양읍)
# 9962    울산기술공업고등학교  고등학교           울산광역시 울주군 온산읍 덕망로 54 . 울산기술공업고등학교 (온산읍)
# 10093       언양고등학교  고등학교                울산광역시 울주군 언양읍 언양로 53 (언양읍. 언양고등학교)
# 10121   울산중앙여자고등학교  고등학교                 울산광역시 중구 내황2길 33 (반구동.울산중앙여자고등학교)
# 10546    울산에너지고등학교  고등학교     울산광역시 북구 화동2길 28 . 울산에너지고등학교 (화봉동. 울산에너지고등학교)
# 10547       온산고등학교  고등학교              울산광역시 울주군 온산읍 명봉거남로 76 (온산읍. 온산고등학교)
# 10837       천상고등학교  고등학교                 울산광역시 울주군 범서읍 당앞로 96 천상고등학교 (범서읍)
# 11132   울산미용예술고등학교  고등학교            울산광역시 울주군 웅촌면 학교길 26 (웅촌면. 울산미용예술고등학교)
# 11269       약사고등학교  고등학교                    울산광역시 중구 종가로 560 (약사동. 약사고등학교)
# 11828       효정고등학교  고등학교                    울산광역시 북구 율동2길 41 (효문동. 효정고등학교)
#
#               위도          경도
# 250    35.556095  129.284450
# 715    35.542589  129.268165
# 719    35.538010  129.418752
# 724    35.562707  129.327842
# 735    35.481864  129.216274
# 842    35.536279  129.250742
# 856    35.482396  129.409180
# 1031   35.563092  129.331135
# 1201   35.632780  129.338851
# 1239   35.538668  129.430889
# 1521   35.535587  129.309596
# 1911   35.515931  129.316772
# 1963   35.588520  129.093275
# 2037   35.566632  129.334949
# 2049   35.566489  129.270610
# 2198   35.549043  129.319224
# 2199   35.538256  129.249962
# 2259   35.631930  129.328846
# 2715   35.630566  129.355038
# 3122   35.476981  129.409585
# 3529   35.545257  129.341331
# 3626   35.541829  129.315974
# 3659   35.644814  129.359529
# 4527   35.532938  129.301991
# 4621   35.556935  129.256036
# 4906   35.623482  129.430854
# 5052   35.632759  129.435202
# 5680   35.543146  129.265849
# 5898   35.555692  129.265401
# 6025   35.586651  129.361613
# 6259   35.553299  129.115724
# 6282   35.531604  129.300327
# 6341   35.525062  129.325946
# 6553   35.525220  129.421669
# 6768   35.536559  129.428097
# 7046   35.595300  129.370021
# 7201   35.658787  129.354175
# 7234   35.526132  129.324339
# 7242   35.505669  129.419009
# 7266   35.561366  129.297289
# 8164   35.598641  129.101571
# 8340   35.560757  129.378178
# 8633   35.504237  129.421011
# 8666   35.569791  129.249325
# 8994   35.529034  129.309887
# 9423   35.578718  129.321120
# 9666   35.504563  129.422904
# 9812   35.414778  129.277213
# 9962   35.438176  129.308529
# 10093  35.561769  129.132019
# 10121  35.554585  129.344155
# 10546  35.590196  129.369392
# 10547  35.438958  129.317842
# 10837  35.565628  129.222112
# 11132  35.465558  129.204701
# 11269  35.573545  129.335998
# 11828  35.563666  129.374997

# %% [markdown]
# ### 3.데이터 시각화

# %%
# zoom_start: 배율 1~22 (여기서는 출력 안함)
# 학성고등학교 위도/경도
map_osm = folium.Map(location=[35.5312509, 129.3002988], zoom_start=12)

html="<font color='green' style='white-space: nowrap'><b>%s</b></font>"

# 데이터프레임의 행 수만큼 반복하면서 마커 생성
for i in df2.index:
    # 행 우선 접근 방식으로 값 추출
    name = df2.loc[i, '학교명']
    lat = df2.loc[i, '위도']
    lng = df2.loc[i, '경도']

    # 추출한 정보를 지도에 표시
    popup_html = folium.Popup(html % name, parse_html=False)
    marker = folium.Marker([lat,lng], popup=popup_html)
    marker.add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48e08cbba0fed6eb88aad8f57b617ab7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48e08cbba0fed6eb88aad8f57b617ab7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48e08cbba0fed6eb88aad8f57b617ab7 = L.map(
#                 &quot;map_48e08cbba0fed6eb88aad8f57b617ab7&quot;,
#                 {
#                     center: [35.5312509, 129.3002988],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74ebd7ec49ee46a4c03e5439a4e0fcc7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_48e08cbba0fed6eb88aad8f57b617ab7);
#
#
#             var marker_ec3ef1d655abe39b416d758493c79723 = L.marker(
#                 [35.5560947437, 129.2844495749],
#                 {}
#             ).addTo(map_48e08cbba0fed6eb88aad8f57b617ab7);
#
#
#         var popup_5c775797e4a7f9afa74c73b1f8bb0e7d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9a378775277f290f73658a74bbec2155 = $(`&lt;div id=&quot;html_9a378775277f290f73658a74bbec2155&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font color=&#x27;green&#x27; style=&#x27;white-space: nowrap&#x27;&gt;&lt;b&gt;울산중앙고등학교&lt;/b&gt;&lt;/font&gt;&lt;/div&gt;`)[0];
#                 popup_5c775797e4a7f9afa74c73b1f8bb0e7d.setContent(html_9a378775277f290f73658a74bbec2155);
#
#
#
#         marker_ec3ef1d655abe39b416d758493c79723.bindPopup(popup_5c775797e4a7f9afa74c73b1f8bb0e7d)
#         ;
#
#
#
#
#             var marker_5866ec16064bd9777514870d96bd68f7 = L.marker(
#                 [35.5425894389, 129.2681645],
#                 {}
#             ).addTo(map_48e08cbba0fed6eb88aad8f57b617ab7);
#
#
#         var popup_03efb7c1d3b605f11c9cd26ebbd2fac8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3447b455e0f5aca0d231b45aa5bf9c64 = $(`&lt;div id=&quot;html_3447b455e0f5aca0d231b45aa5bf9c64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font color=&#x27;green&#x27; style=&#x27;white-space: nowrap&#x27;&gt;&lt;b&gt;울산제일고등학교&lt;/b&gt;&lt;/font&gt;&lt;/div&gt;`)[0];
#                 popup_03efb7c1d3b605f11c9cd26ebbd2fac8.setContent(html_3447b455e0f5aca0d231b45aa5bf9c64);
#
#
#
#         marker_5866ec16064bd9777514870d96bd68f7.bindPopup(popup_03efb7c1d3b605f11c9cd26ebbd2fac8)
#         ;
#
#
#
#
#             var marker_c6d500ca29dbf372f8d521ee8eb11158 = L.marker(
#                 [35.5380104249, 129.4187517071],
#                 {}
#             ).addTo(map_48e08cbba0fed6eb88aad8f57b617ab7);
#
#
#         var popup_11e766734a0b33421c853008a2f63fff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04fd79d19cc73f329dc740f8dcf400ec = $(`&lt;div id=&quot;html_04fd79d19cc73f329dc740f8dcf400ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font color=&#x27;green&#x27; style=&#x27;white-space: nowrap&#x27;&gt;&lt;b&gt;남목고등학교&lt;/b&gt;&lt;/font&gt;&lt;/div&gt;`)[0];
#                 popup_11e766734a0b33421c853008a2f63fff.setContent(html_04fd79d19cc73f329dc740f8dcf400ec);
#
#
#
#         marker_c6d500ca29dbf372f8d521ee8eb11158.bindPopup(popup_11e766734a0b33421c853008a2f63fff)
#         ;
#
#
#
#
#             var marker_1c979d36af226207e7b3d36fa47e5b09 = L.marker(
#                 [35.5627065645, 129.3278415304],
#                 {}
#             ).addTo(map_48e08cbba0fed6eb88aad8f57b617ab7);
#
#
#         var popup_be49cfbc99887c29cbd6f9c394bf5379 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bfdae347c44ddf13c321484aa7b2487b = $(`&lt;div id=&quot;html_bfdae347c44ddf13c321484aa7b2487b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;font color=&#x27;green&#x27; style=&#x27;white-space: nowrap&#x27;&gt;&lt;b&gt;성신고등학교&lt;/b&gt;&lt;/font&gt;&lt;/div&gt;`)[0];
#                 popup_be49cfbc99887c29cbd6f9c394bf5379.setContent(html_bfdae347c44ddf13c321484aa7b2487b);
#
#
#
#         marker_1c979d36af226207e7b3d36fa47e5b09.bindPopup(popup_be49cfbc99887c29cbd6f9c394bf5379)
#         ;
#
#
#
#
#             var marker_89d35cebdc5588d2ec67d8295cfab588 = L.marker(
#                 [35.4818641003, 129.216273775],
#                 {}
#             ).addTo(map_48e08cbba0fed6eb88aad8f57b617ab7);
#
#
#         var popup_d99ed958f154e7f2473deb17b2eeaad0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_03fa54fe10b1b37051bba5296bb114fc = $(`&lt;div id=&quot;html_03fa54fe10b1b37051bba5296bb114fc&quot; style=&quot;width: 10
