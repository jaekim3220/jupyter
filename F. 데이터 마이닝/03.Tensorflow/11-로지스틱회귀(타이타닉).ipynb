# %% [markdown]
# 패키지 참조 -> 데이터 셋 준비 -> 데이터 전처리 -> 탐색적 데이터 분석 -> 데이터 셋 분할 -> 모델 개발 -> 학습 결과 평가 -> 학습 결과 적용
#
# ![res/code.png](res/code.png)
#
# 분석 프로세스를 진행한 이유와 해당 프로세서를 통해 얻은 결론을 설명
# - 모든 단계는 목적과 근거를 제시
#
# >머신러닝 - 소숫점 처리에 뛰어남

# %% [markdown]
# # 로지스틱 회귀 - 타이타닉 생존률 `예측`
#
# 로지스틱회귀는 설명력을 사용하지 않음

# %% [markdown]
# ## #01. 패키지

# %%
import sys
sys.path.append("../../")
import helper

import numpy as np
from pandas import read_excel, DataFrame, get_dummies
from matplotlib import pyplot as plt
import seaborn as sb

from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# ## #02. 데이터셋 준비

# %%
origin = read_excel("https://data.hossam.kr/E05/titanic.xlsx")
origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### #03. 데이터 전처리

# %% [markdown]
# ### 결측치 확인
#
# isna

# %%
origin.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### 결측치 정제

# %% [markdown]
# #### 객실번호(`Cabin`)
#
# 선실이 부여되지 않은 경우 객실 등급에 따른 차이가 있는지 여부를 확인

# %%
print(origin.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_tmp = origin.filter(['Pclass', 'Cabin']).query('Cabin.isnull()')
df_tmp.fillna(0, inplace=True)
df_tmp.groupby('Pclass').count()
# Out:
#         Cabin
# Pclass
# 1          40
# 2         168
# 3         479

# %% [markdown]
# > 객실 번호는 생존 여부에 영향이 없을 것으로 판단하고 변수 자체를 제거 (열단위 제거)

# %%
df1 = origin.drop('Cabin', axis=1)
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %% [markdown]
# #### 탑승지
#
# 탑승지 데이터가 결측치인 경우는 2건 밖에 되지 않기 때문에 데이터 정제 과정에서 제거 (행단위)

# %%
df2 = df1.query('Embarked.notnull()')
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %% [markdown]
# #### 나이를 중앙값으로 대체
#
# 나이의 경우 탑승객의 생존 여부에 중요한 영향을 미치는 요인이라고 짐작하고 삭제하지 않기로 결정하였다.
#
# 연속형 데이터의 결측치를 대체하기에 가장 적합한 값은 중앙값이므로 중앙값으로 대체한다.

# %%
df3 = df2.copy()
df3['Age'].fillna(df3['Age'].median(), inplace=True)
df3.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ### 불필요한 필드 제거

# %% [markdown]
# #### 탑승객 번호
#
# 탑승객 번호는 단순한 일련번호이므로 생존률에 영향을 주지 않는 값이라고 판단하고 이 값을 인덱스로 설정하였다.

# %%
# PassengerId를 DF의 Index로
df4 = df3.set_index("PassengerId")
df4.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500        S
# 2                1      0          PC 17599  71.2833        C
# 3                0      0  STON/O2. 3101282   7.9250        S
# 4                1      0            113803  53.1000        S
# 5                0      0            373450   8.0500        S

# %% [markdown]
# #### 이름과 티켓번호
#
# 생존 여부에 영향을 주지 않는다고 판단하고 제거

# %%
df5 = df4.drop(['Name', 'Ticket'], axis=1)
df5.head()
# Out:
#              Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# PassengerId
# 1                   0       3    male  22.0      1      0   7.2500        S
# 2                   1       1  female  38.0      1      0  71.2833        C
# 3                   1       3  female  26.0      0      0   7.9250        S
# 4                   1       1  female  35.0      1      0  53.1000        S
# 5                   0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# ### 더미변수 처리
#
# 범주형(명목형) 데이터(카테고리가 1~3등급)를 각 카테고리별로 나누어 표현 - 명목형은 계산할 수 있는 값이 아니기 때문
#
# ex) 태아의 성별, 위암 등급, 승무원의 등급

# %%
cda_df = get_dummies(df5, columns=['Pclass', 'Sex', 'Embarked'], drop_first=True, dtype='int')
cda_df.head()
# Out:
#              Survived   Age  SibSp  Parch     Fare  Pclass_2  Pclass_3  \
# PassengerId
# 1                   0  22.0      1      0   7.2500         0         1
# 2                   1  38.0      1      0  71.2833         0         0
# 3                   1  26.0      0      0   7.9250         0         1
# 4                   1  35.0      1      0  53.1000         0         0
# 5                   0  35.0      0      0   8.0500         0         1
#
#              Sex_male  Embarked_Q  Embarked_S
# PassengerId
# 1                   1           0           1
# 2                   0           0           0
# 3                   0           0           1
# 4                   0           0           1
# 5                   1           0           1

# %% [markdown]
# ## #04. 탐색적 데이터 분석
#
# > `E05`의 연습문제 2번으로 진행한바 있으므로 생략

# %% [markdown]
# ## #05. 데이터셋 분할하기

# %% [markdown]
# ### 랜덤시드 고정

# %%
np.random.seed(777)

# %% [markdown]
# ### 훈련 데이터(독립변수)와 레이블(종속변수) 구분하기

# %%
x = cda_df.drop('Survived', axis=1)
x.head()
# Out:
#               Age  SibSp  Parch     Fare  Pclass_2  Pclass_3  Sex_male  \
# PassengerId
# 1            22.0      1      0   7.2500         0         1         1
# 2            38.0      1      0  71.2833         0         0         0
# 3            26.0      0      0   7.9250         0         1         0
# 4            35.0      1      0  53.1000         0         0         0
# 5            35.0      0      0   8.0500         0         1         1
#
#              Embarked_Q  Embarked_S
# PassengerId
# 1                     0           1
# 2                     0           0
# 3                     0           1
# 4                     0           1
# 5                     0           1

# %%
y = cda_df[['Survived']]
y.head()
# Out:
#              Survived
# PassengerId
# 1                   0
# 2                   1
# 3                   1
# 4                   1
# 5                   0

# %% [markdown]
# ### 데이터 표준화
#
# > 일단 생략 - 표준화를 했다면 예측을 위한 값도 표준화 후 삽입해야하기 때문(복잡해짐)

# %% [markdown]
# ### 훈련 데이터와 검증 데이터로 분할

# %%
# 표준화 미진행 - x,y 사용
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=777)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((622, 9), (267, 9), (622, 1), (267, 1))

# %% [markdown]
# ## #06. 모델 개발

# %% [markdown]
# ### 모델 정의
#
# > [relu], sigmoid, rmsporp, binary_crossentropy, acc
#
# - input_shape은 독립변수 수
# - Dense 신경망 개수의 수에 따라서 모델의 성능에 차이가 발생
#     - 직감으로 맞춤(다른 방법 없음) 보통 16 또는 32 이상
#     - 최적의 값을 직접 탐색(너무 많으면 컴퓨터 다운)
# - activation은 모델과 분석 종류에 따라서 다름
#     - 보통 시작은 relu, 분류는 sigmoid, 회귀는 linear
# - optimizer은 모르면 Adam
# - epochs는 많아도 크게 상관이 없음
# - 2차항을 하고 싶다면 sklearn으로 2차항 생성 후 Sequential에 입력

# %%
model = Sequential()
model.add(Dense(32, activation = 'relu', input_shape=(9, )))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss = 'binary_crossentropy', metrics = ['acc'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 32)                320
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 353 (1.38 KB)
# Trainable params: 353 (1.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### 학습하기
#
# - epochs는 많아도 크게 상관이 없음(단, 너무 크면 오래 걸리고 오차가 증가)
#     - callback을 사용해 모델의 학습 방향, 저장 시점, 학습 정지 시점 등에 관한 상황을 모니터링
#     - EarlyStopping 콜백과 같이 patience 인자를 지정하여, 지정된 기간 동안 `평가지표에서 성능 향상이 일어나지 않으면 학습률을 조정하는 콜백`
#     - ReduceLROnPlateau EarlyStopping 콜백과 같이 patience 인자를 지정하여, 지정된 기간 동안 `평가지표에서 성능 향상이 일어나지 않으면 학습률을 조정하는 콜백`
#     - ModelCheckpoint 지정한 평가지표를 기준으로 가장 뛰어난 성능을 보여주는 모델을 저장 할 때 사용

# %%
result = model.fit(x_train, y_train, epochs = 500, validation_data = (x_test, y_test), callbacks = [
    EarlyStopping(monitor = 'val_loss', patience=5, verbose = 1),
    ReduceLROnPlateau(monitor= "val_loss", patience=3, factor = 0.5, min_lr=0.0001, verbose=1)
])
# Out:
# Epoch 1/500
# 20/20 [==============================] - 1s 19ms/step - loss: 4.5569 - acc: 0.6383 - val_loss: 3.9772 - val_acc: 0.5805 - lr: 0.0010
# Epoch 2/500
# 20/20 [==============================] - 0s 3ms/step - loss: 2.5953 - acc: 0.6238 - val_loss: 2.0125 - val_acc: 0.6142 - lr: 0.0010
# Epoch 3/500
# 20/20 [==============================] - 0s 4ms/step - loss: 1.1764 - acc: 0.6511 - val_loss: 0.8064 - val_acc: 0.6255 - lr: 0.0010
# Epoch 4/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6162 - acc: 0.6833 - val_loss: 0.7117 - val_acc: 0.6442 - lr: 0.0010
# Epoch 5/500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.5855 - acc: 0.7026 - val_loss: 0.5812 - val_acc: 0.6891 - lr: 0.0010
# Epoch 6/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5565 - acc: 0.7170 - val_loss: 0.6011 - val_acc: 0.6966 - lr: 0.0010
# Epoch 7/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5482 - acc: 0.7203 - val_loss: 0.5457 - val_acc: 0.7341 - lr: 0.0010
# Epoch 8/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5415 - acc: 0.7315 - val_loss: 0.5449 - val_acc: 0.7303 - lr: 0.0010
# Epoch 9/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5289 - acc: 0.7428 - val_loss: 0.5381 - val_acc: 0.7416 - lr: 0.0010
# Epoch 10/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5232 - acc: 0.7492 - val_loss: 0.5381 - val_acc: 0.7416 - lr: 0.0010
# Epoch 11/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5073 - acc: 0.7605 - val_loss: 0.5229 - val_acc: 0.7491 - lr: 0.0010
# Epoch 12/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5169 - acc: 0.7524 - val_loss: 0.5201 - val_acc: 0.7491 - lr: 0.0010
# Epoch 13/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5088 - acc: 0.7572 - val_loss: 0.5552 - val_acc: 0.7303 - lr: 0.0010
# Epoch 14/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4996 - acc: 0.7669 - val_loss: 0.5146 - val_acc: 0.7528 - lr: 0.0010
# Epoch 15/500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4977 - acc: 0.7556 - val_loss: 0.5858 - val_acc: 0.7116 - lr: 0.0010
# Epoch 16/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4973 - acc: 0.7621 - val_loss: 0.5252 - val_acc: 0.7416 - lr: 0.0010
# Epoch 17/500
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4931 - acc: 0.7797 - val_loss: 0.5056 - val_acc: 0.7528 - lr: 0.0010
# Epoch 18/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4885 - acc: 0.7605 - val_loss: 0.5592 - val_acc: 0.7191 - lr: 0.0010
# Epoch 19/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4927 - acc: 0.7781 - val_loss: 0.5424 - val_acc: 0.7341 - lr: 0.0010
# Epoch 20/500
#  1/20 [>.............................] - ETA: 0s - loss: 0.5723 - acc: 0.7188
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4806 - acc: 0.7878 - val_loss: 0.5479 - val_acc: 0.7453 - lr: 0.0010
# Epoch 21/500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.4789 - acc: 0.7862 - val_loss: 0.5011 - val_acc: 0.7566 - lr: 5.0000e-04
# Epoch 22/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4728 - acc: 0.7830 - val_loss: 0.5013 - val_acc: 0.7566 - lr: 5.0000e-04
# Epoch 23/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4688 - acc: 0.7862 - val_loss: 0.4938 - val_acc: 0.7790 - lr: 5.0000e-04
# Epoch 24/500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.4723 - acc: 0.7830 - val_loss: 0.5238 - val_acc: 0.7378 - lr: 5.0000e-04
# Epoch 25/500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4717 - acc: 0.7878 - val_loss: 0.4946 - val_acc: 0.7753 - lr: 5.0000e-04
# Epoch 26/500
#  1/20 [>.............................] - ETA: 0s - loss: 0.5597 - acc: 0.6875
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4689 - acc: 0.7974 - val_loss: 0.5191 - val_acc: 0.7453 - lr: 5.0000e-04
# Epoch 27/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4661 - acc: 0.7878 - val_loss: 0.5005 - val_acc: 0.7528 - lr: 2.5000e-04
# Epoch 28/500
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4615 - acc: 0.7894 - val_loss: 0.5344 - val_acc: 0.7341 - lr: 2.5000e-04
# Epoch 28: early stopping

# %% [markdown]
# ## #07. 학습결과 평가

# %% [markdown]
# ### 기본적인 머신러닝 학습률 평가

# %%
helper.tf_result_plot(result)
# Out:
#             loss       acc  val_loss   val_acc       lr
# epochs
# 1       4.556942  0.638264  3.977199  0.580524  0.00100
# 2       2.595306  0.623794  2.012524  0.614232  0.00100
# 3       1.176423  0.651125  0.806399  0.625468  0.00100
# 4       0.616151  0.683280  0.711688  0.644195  0.00100
# 5       0.585499  0.702572  0.581200  0.689139  0.00100
# 6       0.556455  0.717042  0.601086  0.696629  0.00100
# 7       0.548171  0.720257  0.545695  0.734082  0.00100
# 8       0.541520  0.731511  0.544887  0.730337  0.00100
# 9       0.528859  0.742765  0.538138  0.741573  0.00100
# 10      0.523250  0.749196  0.538065  0.741573  0.00100
# 11      0.507255  0.760450  0.522901  0.749064  0.00100
# 12      0.516901  0.752412  0.520110  0.749064  0.00100
# 13      0.508818  0.757235  0.555193  0.730337  0.00100
# 14      0.499605  0.766881  0.514647  0.752809  0.00100
# 15      0.497668  0.755627  0.585828  0.711610  0.00100
# 16      0.497348  0.762058  0.525227  0.741573  0.00100
# 17      0.493138  0.779743  0.505576  0.752809  0.00100
# 18      0.488474  0.760450  0.559172  0.719101  0.00100
# 19      0.492717  0.778135  0.542449  0.734082  0.00100
# 20      0.480592  0.787781  0.547892  0.745318  0.00100
# 21      0.478860  0.786174  0.501058  0.756554  0.00050
# 22      0.472776  0.782958  0.501317  0.756554  0.00050
# 23      0.468811  0.786174  0.493773  0.779026  0.00050
# 24      0.472343  0.782958  0.523844  0.737828  0.00050
# 25      0.471715  0.787781  0.494629  0.775281  0.00050
# 26      0.468866  0.797428  0.519065  0.745318  0.00050
# 27      0.466068  0.787781  0.500517  0.752809  0.00025
# 28      0.461492  0.789389  0.534384  0.734082  0.00025

# %%
evaluate1 = model.evaluate(x_train, y_train)
print("최종 훈련 손실률 : %f, 최종 훈련 정확도 : %f" % (evaluate1[0], evaluate1[1]))

evaluate2 = model.evaluate(x_test, y_test)
print("최종 검증 손실률 : %f, 최종 검증 정확도 : %f" % (evaluate2[0], evaluate2[1]))
# Out:
#  1/20 [>.............................] - ETA: 0s - loss: 0.4668 - acc: 0.8125
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4690 - acc: 0.8006
# 최종 훈련 손실률 : 0.468952, 최종 훈련 정확도 : 0.800643
# 9/9 [==============================] - 0s 2ms/step - loss: 0.5344 - acc: 0.7341
# 최종 검증 손실률 : 0.534384, 최종 검증 정확도 : 0.734082

# %% [markdown]
# ### 로지스틱 회귀 결과 검정
#
# > helper 기능 추가

# %%
logit_result = helper.tf_logit_result(model, result, x_train, y_train)
# Out:
# 20/20 [==============================] - 0s 2ms/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 32)                320
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 353 (1.38 KB)
# Trainable params: 353 (1.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
logit_result.cmdf
# Out:
#        Negative  Positive
# True        379       110
# False        14       119

# %%
logit_result.odds_rate_df
# Out:
# array([0.7816318], dtype=float32)

# %%
logit_result.result_df.T
# helper.prettyPrint(logit_result.result_df.T)
# Out:
#                               0
# 정확도(Accuracy)          0.800643
# 정밀도(Precision)         0.894737
# 재현율(Recall, TPR)       0.519651
# 위양성율(Fallout, FPR)     0.035623
# 특이성(Specificity, TNR)  0.964377
# RAS                    0.742014
# f1_score               0.657459

# %% [markdown]
# ## #08. 학습 결과 적용

# %% [markdown]
# ### 실제 데이터로 예측

# %% [markdown]
# #### 예측을 위한 데이터프레임 준비

# %%
test_df = DataFrame({
    'dicaprio': [19, 0, 0, 0, 0, 1, 1, 0, 0],  # 영화속 남자 주인공 데이터
    'winslet': [17, 1, 2, 100, 0, 0, 0, 1, 0], # 영화속 여자 주인공 데이터
    'someone': [41, 1, 0, 50, 1, 0, 1, 0, 0]  # 임의의 데이터(본인이나 주변인)
}, index=['Age','SibSp','Parch','Fare','Pclass_2','Pclass_3','Sex_male','Embarked_Q','Embarked_S'])
test_df
# Out:
#             dicaprio  winslet  someone
# Age               19       17       41
# SibSp              0        1        1
# Parch              0        2        0
# Fare               0      100       50
# Pclass_2           0        0        1
# Pclass_3           1        0        0
# Sex_male           1        0        1
# Embarked_Q         0        1        0
# Embarked_S         0        0        0

# %% [markdown]
# #### 결과 예측하기

# %%
results = model.predict(test_df.T)
data_count, case_count = results.shape
print("%d개의 임의의 데이터는 %d개의 경우의 수를 갖는다." % (data_count, case_count))
print(results)
# Out:
# 1/1 [==============================] - 0s 74ms/step
# 3개의 임의의 데이터는 1개의 경우의 수를 갖는다.
# [[0.10719509]
#  [0.49333313]
#  [0.3887753 ]]

# %%
for i, v in enumerate(results.flatten()):
    print("%s의 생존 확률은 %0.1f%% 입니다." % (test_df.columns[i], v*100))
# Out:
# dicaprio의 생존 확률은 10.7% 입니다.
# winslet의 생존 확률은 49.3% 입니다.
# someone의 생존 확률은 38.9% 입니다.
